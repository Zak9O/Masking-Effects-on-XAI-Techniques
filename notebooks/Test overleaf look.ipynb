# %% [markdown]
# # The Adult Dataset
# in figure below we show the utility across the different models.

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/usa_house/clean.csv")

# %%
df['Price'].nunique()
# Out:
# 6
