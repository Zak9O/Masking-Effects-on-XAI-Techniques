# %%
import pandas as pd

# %%
df = pd.read_csv("../data/usa_house/k_anonymity/2.csv")

# %%
df
# Out:
#              Avg. Area Income          Avg. Area House Age  \
# 0     (73240.663, 104702.724]               (5.544, 6.407]
# 1     (73240.663, 104702.724]               (5.544, 6.407]
# 2       (17796.63, 63887.917]               (5.544, 6.407]
# 3       (17796.63, 63887.917]               (6.407, 9.519]
# 4       (17796.63, 63887.917]  (2.6430000000000002, 5.544]
# ...                       ...                          ...
# 4960    (17796.63, 63887.917]               (6.407, 9.519]
# 4961  (73240.663, 104702.724]               (6.407, 9.519]
# 4962    (17796.63, 63887.917]               (6.407, 9.519]
# 4963   (63887.917, 73240.663]  (2.6430000000000002, 5.544]
# 4964   (63887.917, 73240.663]               (5.544, 6.407]
#
#         Avg. Area Number of Rooms Avg. Area Number of Bedrooms  \
# 0                  (6.568, 7.425]                 (3.27, 4.35]
# 1                  (6.568, 7.425]                (1.999, 3.27]
# 2                  (7.425, 10.28]                  (4.35, 6.5]
# ...
